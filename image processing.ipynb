# %%
# instll Pillow
import PIL
print('Pillow Version:', PIL.__version__)
# Out:
# Pillow Version: 6.1.0

# %% [markdown]
# # Open a single  image stored in the same directory

# %%
# %matplotlib inline
# load and show an image with Pillow
from PIL import Image
# load the image
image = Image.open('opera_house.jpg')
# summarize some details about the image
print(image.format)
print(image.mode)
print(image.size)
# show the image
image.show()
# Out:
# JPEG
# RGB
# (800, 450)

# %% [markdown]
# # How to Convert Images to NumPy Arrays and Back

# %%
# load and display an image with Matplotlib
from matplotlib import image
from matplotlib import pyplot
# load image as pixel array
data = image.imread('opera_house.jpg')
# summarize shape of the pixel array
print(data.dtype)
print(data.shape)
# display the array of pixels as an image
pyplot.imshow(data)
pyplot.show()
# Out:
# uint8
# (450, 800, 3)

# %%
# load image and convert to and from NumPy array
from PIL import Image
from numpy import asarray
# load the image
image = Image.open('opera_house.jpg')
# convert image to numpy array
data = asarray(image)
# summarize shape
print(data.shape)
# create Pillow image
image2 = Image.fromarray(data)
# summarize image details
print(image2.format)
print(image2.mode)
print(image2.size)
# Out:
# (450, 800, 3)
# None
# RGB
# (800, 450)

# %% [markdown]
# # load all images in a directory as a list as follows:

# %%
# load all images in a directory
from os import listdir
from matplotlib import image
# load all images in a directory
loaded_images = list()
for filename in listdir('images'):
# load image
img_data = image.imread('images/' + filename)
# store loaded image
loaded_images.append(img_data)
print('> loaded %s %s' % (filename, img_data.shape))
# Out:
# > loaded image_0001.jpg (205, 300, 3)
# > loaded image_0002.jpg (200, 300, 3)
# > loaded image_0003.jpg (300, 273, 3)
# > loaded image_0004.jpg (235, 300, 3)
# > loaded image_0005.jpg (225, 300)
# > loaded image_0006.jpg (256, 300, 3)
# > loaded image_0007.jpg (289, 300, 3)
# > loaded image_0008.jpg (241, 300, 3)
# > loaded image_0009.jpg (103, 300, 3)
# > loaded image_0010.jpg (177, 300, 3)
# > loaded image_0011.jpg (200, 300)
# > loaded image_0012.jpg (215, 300, 3)
# > loaded image_0013.jpg (177, 300, 3)
# > loaded image_0014.jpg (161, 300, 3)
# > loaded image_0015.jpg (289, 300)
# > loaded image_0016.jpg (239, 300)
# > loaded image_0017.jpg (264, 300, 3)
# > loaded image_0018.jpg (200, 300, 3)
# > loaded image_0019.jpg (201, 300, 3)
# > loaded image_0020.jpg (225, 300, 3)
# > loaded image_0021.jpg (284, 300, 3)
# > loaded image_0022.jpg (190, 300, 3)
# > loaded image_0023.jpg (227, 300)
# > loaded image_0024.jpg (272, 299, 3)
# > loaded image_0025.jpg (184, 300, 3)
# > loaded image_0026.jpg (173, 300, 3)
# > loaded image_0027.jpg (167, 300)
# > loaded image_0028.jpg (194, 300, 3)
# > loaded image_0029.jpg (163, 300, 3)
# > loaded image_0030.jpg (273, 300, 3)
# > loaded image_0031.jpg (200, 300, 3)
# > loaded image_0032.jpg (165, 300, 3)
# > loaded image_0033.jpg (214, 300, 3)
# > loaded image_0034.jpg (129, 300, 3)
# > loaded image_0035.jpg (224, 300, 3)
# > loaded image_0036.jpg (245, 300)
# > loaded image_0037.jpg (236, 300, 3)
# > loaded image_0038.jpg (170, 300)
# > loaded image_0039.jpg (214, 300, 3)
# > loaded image_0040.jpg (220, 300, 3)
# > loaded image_0041.jpg (193, 300, 3)
# > loaded image_0042.jpg (177, 300, 3)

# %% [markdown]
# # How to Save Images to File

# %%
# example of saving an image in another format
from PIL import Image
# load the image
image = Image.open('opera_house.jpg')
# save as PNG format
image.save('opera_house.png', format='PNG')
# load the image again and inspect the format
image2 = Image.open('opera_house.png')
print(image2.format)
# Out:
# PNG

# %% [markdown]
# # There are a number of ways to convert an image to grayscale, but Pillow #provides the convert() function and
# #the mode ‘L‘ will convert an image to grayscale.

# %%
# example of saving a grayscale version of a loaded image
from PIL import Image
# load the image
image = Image.open('opera_house.jpg')
# convert the image to grayscale
gs_image = image.convert(mode='L')
# save in jpeg format
gs_image.save('opera_house_grayscale.jpg')
# load the image again and show it
image2 = Image.open('opera_house_grayscale.jpg')

# show the image
image2.show()
pyplot.imshow(image2)

# %%
# create a thumbnail of an image
from PIL import Image
# load the image
image = Image.open('opera_house.jpg')
# report the size of the image
print(image.size)
# create a thumbnail and preserve aspect ratio
image.thumbnail((100,100))
# report the size of the thumbnail
print(image.size)
# Out:
# (800, 450)
# (100, 56)

# %% [markdown]
# # how to resize a new image and ignore the original aspect ratio.

# %%
# resize image and force a new shape
from PIL import Image
# load the image
image = Image.open('opera_house.jpg')
# report the size of the image
print(image.size)
# resize image and ignore original aspect ratio
img_resized = image.resize((200,200))
# report the size of the thumbnail
print(img_resized.size)
# Out:
# (800, 450)
# (200, 200)

# %% [markdown]
# # Flip Image

# %%
# create flipped versions of an image
from PIL import Image
from matplotlib import pyplot
# load image
image = Image.open('opera_house.jpg')
# horizontal flip
hoz_flip = image.transpose(Image.FLIP_LEFT_RIGHT)
# vertical flip
ver_flip = image.transpose(Image.FLIP_TOP_BOTTOM)
# plot all three images using matplotlib
pyplot.subplot(311)
pyplot.imshow(image)
pyplot.subplot(312)
pyplot.imshow(hoz_flip)
pyplot.subplot(313)
pyplot.imshow(ver_flip)
pyplot.show()

# %%
# create flipped versions of an image
from PIL import Image
from matplotlib import pyplot
# load image
image = Image.open('opera_house.jpg')
# vertical flip
ver_flip = image.transpose(Image.FLIP_TOP_BOTTOM)

pyplot.imshow(ver_flip)

# %%
# create flipped versions of an image
from PIL import Image
from matplotlib import pyplot
# load image
image = Image.open('opera_house.jpg')
# horizontal flip
hoz_flip = image.transpose(Image.FLIP_LEFT_RIGHT)
pyplot.imshow(hoz_flip)

# %%
# Rotate Image

# %%
# create rotated versions of an image
from PIL import Image
from matplotlib import pyplot
# load image
image = Image.open('opera_house.jpg')
# plot original image
pyplot.subplot(311)
pyplot.imshow(image)
# rotate 45 degrees
pyplot.subplot(312)
pyplot.imshow(image.rotate(45))
# rotate 90 degrees
pyplot.subplot(313)
pyplot.imshow(image.rotate(90))
pyplot.show()

# %%
Cropped Image

# %%
# example of cropping an image
from PIL import Image
# load image
image = Image.open('opera_house.jpg')
# create a cropped image
cropped = image.crop((100, 100, 200, 200))
# show cropped image
cropped.show()
pyplot.imshow(cropped)
