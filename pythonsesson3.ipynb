# %%
import pandas as pd

# %%
df=pd.read_csv('rice.csv',header=None)

# %%
df
# Out:
#         0      1                2                3                  4  \
# 0    Year  Month  Price_beef_kilo  Price_rice_kilo  Price_coffee_kilo
# 1    1992    Feb             2.52             0.28               1.51
# 2    1992    Mar             2.45             0.28               1.55
# 3    1992    Apr             2.38             0.28               1.45
# 4    1992    May             2.38             0.27               1.34
# ..    ...    ...              ...              ...                ...
# 356  2021    Sep             5.66              0.4               4.97
# 357  2021    Oct              5.7              0.4               5.31
# 358  2021    Nov             5.95              0.4               5.71
# 359  2021    Dec             5.95              0.4               5.91
# 360  2022    Jan             5.97             0.43               5.98
#
#                   5                6                7                  8
# ...

# %%
df1=pd.read_csv('diabetes.csv',header=None)

# %%
df1
# Out:
#                0        1              2              3        4     5  \
# 0    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1              6      148             72             35        0  33.6
# 2              1       85             66             29        0  26.6
# 3              8      183             64              0        0  23.3
# 4              1       89             66             23       94  28.1
# ..           ...      ...            ...            ...      ...   ...
# 764           10      101             76             48      180  32.9
# 765            2      122             70             27        0  36.8
# 766            5      121             72             23      112  26.2
# 767            1      126             60              0        0  30.1
# 768            1       93             70             31        0  30.4
#
#                             6    7        8
# 0    DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
import csv

# %%
preg=[]
t=[]

# %%
f=open('diabetes.csv')
csv_f=csv.reader(f)
for row in csv_f:
    preg.append(row[1])
    t.append(row[2])

# %%
t
# Out:
# ['BloodPressure',
#  '72',
#  '66',
#  '64',
#  '66',
#  '40',
#  '74',
#  '50',
#  '0',
#  '70',
#  '96',
#  '92',
#  '74',
#  '80',
#  '60',
#  '72',
#  '0',
#  '84',
#  '74',
#  '30',
#  '70',
#  '88',
#  '84',
#  '90',
#  '80',
#  '94',
#  '70',
#  '76',
#  '66',
#  '82',
#  '92',
#  '75',
#  '76',
#  '58',
#  '92',
#  '78',
#  '60',
#  '76',
#  '76',
#  '68',
#  '72',
#  '64',
#  '84',
#  '92',
#  '110',
#  '64',
#  '66',
#  '56',
#  '70',
#  '66',
#  '0',
#  '80',
#  '50',
#  '66',
#  '90',
#  '66',
#  '50',
#  '68',
#  '88',
#  '82',
#  '64',
#  '0',
#  '72',
#  '62',
#  '58',
#  '66',
#  '74',
#  '88',
#  '92',
#  '66',
#  '85',
#  '66',
#  '64',
#  '90',
#  '86',
#  '75',
#  '48',
#  '78',
#  '72',
#  '0',
#  '66',
#  '44',
#  '0',
#  '78',
#  '65',
#  '108',
#  '74',
#  '72',
#  '68',
#  '70',
#  '68',
#  '55',
#  '80',
#  '78',
#  '72',
#  '82',
#  '72',
#  '62',
#  '48',
#  '50',
#  '90',
#  '72',
#  '60',
#  '96',
#  '72',
#  '65',
#  '56',
#  '122',
#  '58',
#  '58',
# ...

# %%
preg
# Out:
# ['Glucose',
#  '148',
#  '85',
#  '183',
#  '89',
#  '137',
#  '116',
#  '78',
#  '115',
#  '197',
#  '125',
#  '110',
#  '168',
#  '139',
#  '189',
#  '166',
#  '100',
#  '118',
#  '107',
#  '103',
#  '115',
#  '126',
#  '99',
#  '196',
#  '119',
#  '143',
#  '125',
#  '147',
#  '97',
#  '145',
#  '117',
#  '109',
#  '158',
#  '88',
#  '92',
#  '122',
#  '103',
#  '138',
#  '102',
#  '90',
#  '111',
#  '180',
#  '133',
#  '106',
#  '171',
#  '159',
#  '180',
#  '146',
#  '71',
#  '103',
#  '105',
#  '103',
#  '101',
#  '88',
#  '176',
#  '150',
#  '73',
#  '187',
#  '100',
#  '146',
#  '105',
#  '84',
#  '133',
#  '44',
#  '141',
#  '114',
#  '99',
#  '109',
#  '109',
#  '95',
#  '146',
#  '100',
#  '139',
#  '126',
#  '129',
#  '79',
#  '0',
#  '62',
#  '95',
#  '131',
#  '112',
#  '113',
#  '74',
#  '83',
#  '101',
#  '137',
#  '110',
#  '106',
#  '100',
#  '136',
#  '107',
#  '80',
#  '123',
#  '81',
#  '134',
#  '142',
#  '144',
#  '92',
#  '71',
#  '93',
#  '122',
#  '163',
# ...

# %%
preg.pop(0)
# Out:
# 'Glucose'

# %%
preg.remove('148')

# %%
preg
# Out:
# ['85',
#  '183',
#  '89',
#  '137',
#  '116',
#  '78',
#  '115',
#  '197',
#  '125',
#  '110',
#  '168',
#  '139',
#  '189',
#  '166',
#  '100',
#  '118',
#  '107',
#  '103',
#  '115',
#  '126',
#  '99',
#  '196',
#  '119',
#  '143',
#  '125',
#  '147',
#  '97',
#  '145',
#  '117',
#  '109',
#  '158',
#  '88',
#  '92',
#  '122',
#  '103',
#  '138',
#  '102',
#  '90',
#  '111',
#  '180',
#  '133',
#  '106',
#  '171',
#  '159',
#  '180',
#  '146',
#  '71',
#  '103',
#  '105',
#  '103',
#  '101',
#  '88',
#  '176',
#  '150',
#  '73',
#  '187',
#  '100',
#  '146',
#  '105',
#  '84',
#  '133',
#  '44',
#  '141',
#  '114',
#  '99',
#  '109',
#  '109',
#  '95',
#  '146',
#  '100',
#  '139',
#  '126',
#  '129',
#  '79',
#  '0',
#  '62',
#  '95',
#  '131',
#  '112',
#  '113',
#  '74',
#  '83',
#  '101',
#  '137',
#  '110',
#  '106',
#  '100',
#  '136',
#  '107',
#  '80',
#  '123',
#  '81',
#  '134',
#  '142',
#  '144',
#  '92',
#  '71',
#  '93',
#  '122',
#  '163',
#  '151',
#  '125',
# ...

# %%
import MySQLdb as mdb
con = mdb.connect('localhost','user52','user52','dbname')
# connection = mdb.connect(Mysqlserver,user,password,database)
cur = con.cursor()
cur.execute("create table students (name varchar(10),gender varchar(6))")
con.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-48-7323375145a4> in <module>
# ----> 1 import MySQLdb as mdb
#       2 con = mdb.connect('localhost','user52','user52','dbname')
#       3 # connection = mdb.connect(Mysqlserver,user,password,database)
#       4 cur = con.cursor()
#       5 cur.execute("create table students (name varchar(10),gender varchar(6))")
#
# ModuleNotFoundError: No module named 'MySQLdb'

# %%
import re

# %%
print(dir(re))
# Out:
# ['A', 'ASCII', 'DEBUG', 'DOTALL', 'I', 'IGNORECASE', 'L', 'LOCALE', 'M', 'MULTILINE', 'Match', 'Pattern', 'RegexFlag', 'S', 'Scanner', 'T', 'TEMPLATE', 'U', 'UNICODE', 'VERBOSE', 'X', '_MAXCACHE', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '__version__', '_cache', '_compile', '_compile_repl', '_expand', '_locale', '_pickle', '_special_chars_map', '_subx', 'compile', 'copyreg', 'enum', 'error', 'escape', 'findall', 'finditer', 'fullmatch', 'functools', 'match', 'purge', 'search', 'split', 'sre_compile', 'sre_parse', 'sub', 'subn', 'template']

# %%
mystring='python'

# %%
print(help(re.match))
# Out:
# Help on function match in module re:
#
# match(pattern, string, flags=0)
#     Try to apply the pattern at the start of the string, returning
#     a Match object, or None if no match was found.
#
# None

# %%
mystring
# Out:
# 'python'

# %%
print (re.match('p',mystring))
print (re.match('py',mystring))
print (re.match('pyt',mystring))

print (re.match('pyth',mystring))
print (re.match('pytho',mystring))
print (re.match('python',mystring))

print (re.match('pythons',mystring)) # pythons is not substring of python
print (re.match('ython',mystring))   # no

print (re.match('Python',mystring,re.I))
# Out:
# <re.Match object; span=(0, 1), match='p'>
# <re.Match object; span=(0, 2), match='py'>
# <re.Match object; span=(0, 3), match='pyt'>
# <re.Match object; span=(0, 4), match='pyth'>
# <re.Match object; span=(0, 5), match='pytho'>
# <re.Match object; span=(0, 6), match='python'>
# None
# None
# <re.Match object; span=(0, 6), match='python'>

# %%
import re

# %%
st1='python is a language'
st2='most useful language is python.'
re.search('python',st1)
re.search('py',st2)
# Out:
# <re.Match object; span=(24, 26), match='py'>

# %%
re.search('a',st1)
# Out:
# <re.Match object; span=(10, 11), match='a'>

# %%
my_word1 = "subba"
print (re.search('....',my_word1).group())
# group
#print (re.search('....',my_word1).group())
print (re.search('^..',my_word1).group())
# Out:
# subb
# su

# %%
import logging

# %%
dir(logging)
# Out:
# ['BASIC_FORMAT',
#  'BufferingFormatter',
#  'CRITICAL',
#  'DEBUG',
#  'ERROR',
#  'FATAL',
#  'FileHandler',
#  'Filter',
#  'Filterer',
#  'Formatter',
#  'Handler',
#  'INFO',
#  'LogRecord',
#  'Logger',
#  'LoggerAdapter',
#  'Manager',
#  'NOTSET',
#  'NullHandler',
#  'PercentStyle',
#  'PlaceHolder',
#  'RootLogger',
#  'StrFormatStyle',
#  'StreamHandler',
#  'StringTemplateStyle',
#  'Template',
#  'WARN',
#  'WARNING',
#  '_STYLES',
#  '_StderrHandler',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__date__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__status__',
#  '__version__',
#  '_acquireLock',
#  '_addHandlerRef',
#  '_checkLevel',
#  '_defaultFormatter',
#  '_defaultLastResort',
#  '_handlerList',
#  '_handlers',
#  '_levelToName',
#  '_lock',
#  '_logRecordFactory',
#  '_loggerClass',
#  '_nameToLevel',
#  '_register_at_fork_reinit_lock',
#  '_releaseLock',
# ...

# %%
logging.debug('hi')

# %%
import logging
logging.debug("This is a debug message")
logging.info("This is an information message")
logging.warning("This is an warning message")
logging.error("This is an error message")
logging.critical("This is an critical message")
# Out:
# WARNING:root:This is an warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is an critical message

# %%
import logging
logging.basicConfig(filename="example2.txt",level=logging.DEBUG,filemode='a',format='%(asctime)s - %(levelname)s - %(name)s -  %(message)s',datefmt='%c')
logging.debug("This is a debug message")
logging.info("This is an information message")
logging.warning("This is an warning message")
logging.error("This is an error  message")
logging.critical("This is an critical message")
# Out:
# WARNING:root:This is an warning message
# ERROR:root:This is an error  message
# CRITICAL:root:This is an critical message

# %%
# banking - Function
balance = 0

def deposit(amount):
    global balance
    balance = balance + amount
    return balance

def withdraw(amount):
    global balance
    balance = balance - amount
    return balance

# Eric
deposit(1000)
print ("balance amount for Eric {}".format(balance))
withdraw(300)
print ("balance amount for Eric {}".format(balance))
# Out:
# balance amount for Eric 1000
# balance amount for Eric 700

# %%
balance=0
def deposit(amount):
    global balance
    balance=balance+amount
    return balance
def withdraw(amount):
    global balance 
    balance =balance-amount
    return balance
deposit(1000)
print('the balance of rick is {}'.format(balance))
withdraw(200)
withdraw(200)
print('the balance of rick is {}'.format(balance))
# Out:
# the balance of rick is 1000
# the balance of rick is 600

# %%
# banking - dictionary

def account():
    return {'balance':0}

def deposit(user,amount):
    user['balance'] = user['balance'] + amount
    return user['balance']

def withdraw(user,amount):
    user['balance'] = user['balance'] - amount
    return user['balance']
# focus is on creating different instances 
# Eric
eric = account()
print (eric)
rachel = account()
print (rachel)
# Out:
# {'balance': 0}
# {'balance': 0}

# %%
# eric
deposit(eric,1000)
print ("balance of eric is {}".format(eric['balance']))
deposit(rachel,2000)
print ("balance of rachel is {}".format(rachel['balance']))
# Out:
# balance of eric is 1000
# balance of rachel is 2000

# %%
class emp():
    def __init__(self):
        self.name=''
        self.num=0
        self.sal=0.0
    def getsalary(self):
        return self.salary
    def getname(self):
        return self.name
    def getnum(self):
        return self.num
    def printemp(self):
        print("emp name: {},emp num: {},emp sal: {}".format(self.name,self.num,self.sal))

# %%
navi=emp()
nani=emp()

# %%
nani.salay=1000
nani.name='nani'
nani.num=22

# %%
nani.printemp()
# Out:
# emp name: nani,emp num: 22,emp sal: 0.0

# %%
def account():
    return {'balance':0}

def deposit(user,amount):
    user['balance'] = user['balance'] + amount
    return user['balance']

def withdraw(user,amount):
    user['balance'] = user['balance'] - amount
    return user['balance']
# focus is on creating different instances 
# Eric
eric = account()
print (eric)
rachel = account()
print (rachel)
# Out:
# {'balance': 0}
# {'balance': 0}

# %%
deposit(eric,1000)
print ("balance of eric is {}".format(eric['balance']))
deposit(rachel,2000)
print ("balance of rachel is {}".format(rachel['balance']))
# Out:
# balance of eric is 1000
# balance of rachel is 2000

# %%
withdraw(eric,200)
# Out:
# 800

# %%
print(eric)
# Out:
# {'balance': 800}

# %%
class dog:
    def __init__(self, name, feet):
        self.name=name
        self.feet=feet

# %%
a=dog('nani',5)

# %%
a.name
# Out:
# 'nani'

# %%
a.feet
# Out:
# 5

# %%
class Employee(object):
    def __init__(self, _num=0, _name='', _salary=0.0):
        self.num = _num
        self.name = _name
        self.salary = _salary
        
    def print_data(self):
        print ('EmpId: {}, EmpName: {}, EmpSalary: {}'.format(self.num,
                                                             self.name,
                                                             self.salary))
    def calculate_tax(self):
        slab = (self.salary * 12) - 300000
        tax = 0
        if slab > 0:
            tax = slab * 0.1
        print ("tax for empid: {} is {}".format(self.num, tax))
        
e1 = Employee(1234, 'John', 23600.0) # e1.__init__(1234, 'John', 23500)
e2 = Employee(1235, 'Samanta', 45000.0) # e2.__init__(1235, 'Samanta', 45000.0)
e1.print_data()
e2.print_data()
# Out:
# EmpId: 1234, EmpName: John, EmpSalary: 23600.0
# EmpId: 1235, EmpName: Samanta, EmpSalary: 45000.0

# %%
class emp1:
    def __init__(self,name,num,salary):
        self.name=name
        self.num=num
        self.salary=salary
    def printemp(self):
        print('emp nameis :{},emp num:{}and emp salary is :{}'.format(self.name,self.num,self.salary))
    def calctaxemp(self):
        tax=(self.salary*12) +((self.salary*12)*.35)
        return tax

# %%
nani=emp1('nan1',1234,1234566.99)

# %%
nani.printemp()
# Out:
# emp nameis :nan1,emp num:1234and emp salary is :1234566.99

# %%
nani.calctaxemp()
# Out:
# 19999985.237999998

# %%
class account:
    balance=0
    def deposit(self):
        self.balance=balance
        print('balence is {}'.format(self.balance))

# %%
aa=account()

# %%
type(aa)
# Out:
# __main__.account

# %%
aa.depost=100

# %%
account()

# %%
aa.deposit()
# Out:
# balence is 600

# %%
aa.deposit=100

# %%
type(aa)
# Out:
# __main__.account

# %%
aa.
